# %% [markdown]
# ### Importar bibliotecas

# %%
import os

import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import LSTM
import matplotlib.pyplot as plt
from statsmodels.tools.eval_measures import mse

# %% [markdown]
# ### Carregar dados

# %%
# Carrega dados do CPU
machine = 'm_3330.csv'
workload = pd.read_csv(machine, 
             names = ['machine_id', 'time_stamp', 'cpu', 'mem', 'mem_gps', 
                      'mkpi', 'net_in', 'net_out', 'disk_io_percent'])
workload.time_stamp = pd.to_datetime(workload.time_stamp, unit='s')
workload.set_index('time_stamp', inplace=True)
workload = workload.resample('1min').interpolate()
workload
# Out:
#                     machine_id   cpu   mem  mem_gps  mkpi  net_in  net_out  \
# time_stamp
# 1970-01-01 00:00:00     m_3330  17.0  92.0      NaN   NaN   45.21    38.10
# 1970-01-01 00:01:00     m_3330  24.0  92.0      NaN   NaN   45.21    38.10
# 1970-01-01 00:02:00     m_3330  16.0  91.0      NaN   NaN   45.21    38.10
# 1970-01-01 00:03:00     m_3330  16.0  92.0      NaN   NaN   45.22    38.10
# 1970-01-01 00:04:00     m_3330  16.0  92.0      NaN   NaN   45.22    38.10
# ...                        ...   ...   ...      ...   ...     ...      ...
# 1970-01-08 23:55:00     m_3330  25.0  92.0     5.17   0.0   62.64    55.28
# 1970-01-08 23:56:00     m_3330  21.0  90.0     7.04   1.0   62.64    55.28
# 1970-01-08 23:57:00     m_3330  26.0  90.0     4.41   0.0   62.65    55.28
# 1970-01-08 23:58:00     m_3330  23.0  90.0     5.47   0.0   62.65    55.29
# 1970-01-08 23:59:00     m_3330  21.0  90.0     5.93   0.0   62.65    55.29
#
#                      disk_io_percent
# time_stamp
# 1970-01-01 00:00:00              3.0
# 1970-01-01 00:01:00              4.0
# 1970-01-01 00:02:00              4.0
# 1970-01-01 00:03:00              4.0
# 1970-01-01 00:04:00              4.0
# ...                              ...
# 1970-01-08 23:55:00              4.0
# 1970-01-08 23:56:00              4.0
# 1970-01-08 23:57:00              4.0
# 1970-01-08 23:58:00              4.0
# 1970-01-08 23:59:00              7.0
#
# [11520 rows x 8 columns]

# %% [markdown]
# ### Separar treino e teste

# %%
# Separa conjunto de treino e de teste dos dados de CPU
test_perc = 1/(len(workload)//60)
test_len = int(len(workload)*test_perc)
str_test_perc = f'{test_len/len(workload):0.2f}'
train_set = workload.cpu[:-test_len]
test_set = workload.cpu[-test_len:]

# normaliza os dados de treino
reshaped_train_set = np.reshape(train_set.values, (-1, 1)) # carrega os dados de CPU em 2D
normalizer = MinMaxScaler(feature_range = (0,1)) # normaliza os valores entre 0 e 1
normalized_train_set = normalizer.fit_transform(reshaped_train_set)

# %% [markdown]
# ### Rede Neural

# %%
# Parâmetros de treinamento da rede
epochs = 100
dropout1 = 0.5
dropout2 = 0.5
dropout3 = 0.5
    
def raw(v):
    '''Formata strings que serão usadas no nome do modelo'''
    return str(v).replace('.csv','').replace('.','')

model_name = f'saved_models/rnn_{raw(str_test_perc)}_{epochs}_{raw(dropout1)}_{raw(dropout2)}_{raw(dropout3)}_{raw(machine)}.keras'
if os.path.isfile(model_name):
    ### Carrega o modelo existente
    regressor = load_model(model_name)
else:
    ### Cria um novo modelo
    # Prepara os dados de entrada da rede

    previsors = []
    expected_values = []

    for i in range(30,len(reshaped_train_set)):
        previsors.append(normalized_train_set[i-30:i,0]) # guarda listas de 30 valores (Ex: posições 0 a 29)
        expected_values.append(normalized_train_set[i,0])# guarda o valor seguinte da lista para a rede prever (Ex: posição 90)

    previsors, expected_values = np.array(previsors), np.array(expected_values)
    previsors = np.reshape(previsors,(previsors.shape[0], previsors.shape[1],1)) # [[previsors, expected_values]]  Novo shape: (train_len-90, 90, 1)

    # Configuração da rede
    regressor = Sequential()
    regressor.add(LSTM(units = 100,
                       return_sequences = True,
                       input_shape = (previsors.shape[1],1)))
    regressor.add(Dropout(dropout1))
    regressor.add(LSTM(units = 50,
                       return_sequences = True,))
    regressor.add(Dropout(dropout2))
    regressor.add(LSTM(units = 50))
    regressor.add(Dropout(dropout3))
    regressor.add(Dense(units = 1,
                        activation = 'linear'))
    
    # Treina a rede e cria o modelo
    regressor.compile(optimizer = 'rmsprop',
                      loss = 'mean_squared_error',
                      metrics = ['mean_absolute_error'])
    regressor.fit(previsors,
                  expected_values,
                  epochs = epochs,
                  batch_size = 32)

    # Salva o modelo em um arquivo
    regressor.save(model_name)
    print(f"Modelo salvo em: '{model_name}' ")
# Out:
# Epoch 1/100
# 358/358 [==============================] - 19s 34ms/step - loss: 0.0179 - mean_absolute_error: 0.1003
# Epoch 2/100
# 358/358 [==============================] - 12s 35ms/step - loss: 0.0128 - mean_absolute_error: 0.0850
# Epoch 3/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0112 - mean_absolute_error: 0.0788
# Epoch 4/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0101 - mean_absolute_error: 0.0742
# Epoch 5/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0099 - mean_absolute_error: 0.0729
# Epoch 6/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0096 - mean_absolute_error: 0.0719
# Epoch 7/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0095 - mean_absolute_error: 0.0711
# Epoch 8/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0093 - mean_absolute_error: 0.0707
# Epoch 9/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0092 - mean_absolute_error: 0.0698
# Epoch 10/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0092 - mean_absolute_error: 0.0703
# Epoch 11/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0091 - mean_absolute_error: 0.0699
# Epoch 12/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0090 - mean_absolute_error: 0.0695
# Epoch 13/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0089 - mean_absolute_error: 0.0691
# Epoch 14/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0089 - mean_absolute_error: 0.0690
# Epoch 15/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0091 - mean_absolute_error: 0.0697
# Epoch 16/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0090 - mean_absolute_error: 0.0694
# Epoch 17/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0089 - mean_absolute_error: 0.0689
# Epoch 18/100
# 358/358 [==============================] - 12s 35ms/step - loss: 0.0089 - mean_absolute_error: 0.0693
# Epoch 19/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0089 - mean_absolute_error: 0.0689
# Epoch 20/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0089 - mean_absolute_error: 0.0688
# Epoch 21/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0089 - mean_absolute_error: 0.0687
# Epoch 22/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0090 - mean_absolute_error: 0.0691
# Epoch 23/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0089 - mean_absolute_error: 0.0687
# Epoch 24/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0089 - mean_absolute_error: 0.0687
# Epoch 25/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0090 - mean_absolute_error: 0.0689
# Epoch 26/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0088 - mean_absolute_error: 0.0684
# Epoch 27/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0089 - mean_absolute_error: 0.0689
# Epoch 28/100
# 358/358 [==============================] - 12s 35ms/step - loss: 0.0089 - mean_absolute_error: 0.0689
# Epoch 29/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0088 - mean_absolute_error: 0.0682
# Epoch 30/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0089 - mean_absolute_error: 0.0687
# Epoch 31/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0089 - mean_absolute_error: 0.0689
# Epoch 32/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0089 - mean_absolute_error: 0.0685
# Epoch 33/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0089 - mean_absolute_error: 0.0687
# Epoch 34/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0088 - mean_absolute_error: 0.0683
# Epoch 35/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0088 - mean_absolute_error: 0.0682
# Epoch 36/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0088 - mean_absolute_error: 0.0682
# Epoch 37/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0089 - mean_absolute_error: 0.0685
# Epoch 38/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0088 - mean_absolute_error: 0.0685
# Epoch 39/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0087 - mean_absolute_error: 0.0678
# Epoch 40/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0088 - mean_absolute_error: 0.0684
# Epoch 41/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0088 - mean_absolute_error: 0.0683
# Epoch 42/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0088 - mean_absolute_error: 0.0683
# Epoch 43/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0088 - mean_absolute_error: 0.0682
# Epoch 44/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0088 - mean_absolute_error: 0.0685
# Epoch 45/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0088 - mean_absolute_error: 0.0684
# Epoch 46/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0088 - mean_absolute_error: 0.0682
# Epoch 47/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0087 - mean_absolute_error: 0.0679
# Epoch 48/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0086 - mean_absolute_error: 0.0678
# Epoch 49/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0088 - mean_absolute_error: 0.0684
# Epoch 50/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0087 - mean_absolute_error: 0.0681
# Epoch 51/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0087 - mean_absolute_error: 0.0681
# Epoch 52/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0087 - mean_absolute_error: 0.0681
# Epoch 53/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0087 - mean_absolute_error: 0.0682
# Epoch 54/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0087 - mean_absolute_error: 0.0678
# Epoch 55/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0088 - mean_absolute_error: 0.0682
# Epoch 56/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0086 - mean_absolute_error: 0.0677
# Epoch 57/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0087 - mean_absolute_error: 0.0684
# Epoch 58/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0087 - mean_absolute_error: 0.0676
# Epoch 59/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0087 - mean_absolute_error: 0.0679
# Epoch 60/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0085 - mean_absolute_error: 0.0672
# Epoch 61/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0088 - mean_absolute_error: 0.0681
# Epoch 62/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0087 - mean_absolute_error: 0.0679
# Epoch 63/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0087 - mean_absolute_error: 0.0677
# Epoch 64/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0087 - mean_absolute_error: 0.0679
# Epoch 65/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0086 - mean_absolute_error: 0.0680
# Epoch 66/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0087 - mean_absolute_error: 0.0677
# Epoch 67/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0087 - mean_absolute_error: 0.0678
# Epoch 68/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0086 - mean_absolute_error: 0.0674
# Epoch 69/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0086 - mean_absolute_error: 0.0677
# Epoch 70/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0086 - mean_absolute_error: 0.0673
# Epoch 71/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0086 - mean_absolute_error: 0.0678
# Epoch 72/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0087 - mean_absolute_error: 0.0681
# Epoch 73/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0086 - mean_absolute_error: 0.0677
# Epoch 74/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0086 - mean_absolute_error: 0.0675
# Epoch 75/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0086 - mean_absolute_error: 0.0675
# Epoch 76/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0086 - mean_absolute_error: 0.0679
# Epoch 77/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0086 - mean_absolute_error: 0.0674
# Epoch 78/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0086 - mean_absolute_error: 0.0678
# Epoch 79/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0085 - mean_absolute_error: 0.0673
# Epoch 80/100
# 358/358 [==============================] - 12s 35ms/step - loss: 0.0086 - mean_absolute_error: 0.0675
# Epoch 81/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0087 - mean_absolute_error: 0.0677
# Epoch 82/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0086 - mean_absolute_error: 0.0674
# Epoch 83/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0086 - mean_absolute_error: 0.0675
# Epoch 84/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0086 - mean_absolute_error: 0.0673
# Epoch 85/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0086 - mean_absolute_error: 0.0677
# Epoch 86/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0086 - mean_absolute_error: 0.0674
# Epoch 87/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0087 - mean_absolute_error: 0.0678
# Epoch 88/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0086 - mean_absolute_error: 0.0674
# Epoch 89/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0085 - mean_absolute_error: 0.0673
# Epoch 90/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0086 - mean_absolute_error: 0.0677
# Epoch 91/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0086 - mean_absolute_error: 0.0677
# Epoch 92/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0086 - mean_absolute_error: 0.0675
# Epoch 93/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0086 - mean_absolute_error: 0.0674
# Epoch 94/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0085 - mean_absolute_error: 0.0675
# Epoch 95/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0086 - mean_absolute_error: 0.0679
# Epoch 96/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0085 - mean_absolute_error: 0.0671
# Epoch 97/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0085 - mean_absolute_error: 0.0674
# Epoch 98/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0085 - mean_absolute_error: 0.0674
# Epoch 99/100
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0087 - mean_absolute_error: 0.0680
# Epoch 100/100
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0086 - mean_absolute_error: 0.0678
# Modelo salvo em: 'saved_models/rnn_001_100_05_05_05_m_3330.keras'

# %%
# Carga do modelo e previsão
inputs = test_set.values
inputs = inputs.reshape(-1,1)
inputs = normalizer.transform(inputs)

predict = []
for j in range(30,len(test_set)):
    predict.append(inputs[j-30:j, 0])
predict = np.array(predict)
predict = np.reshape(predict,
                     (predict.shape[0],
                      predict.shape[1],
                      1))
predict = regressor.predict(predict)
predict = normalizer.inverse_transform(predict)

# %% [markdown]
# ### Compara previsão com teste

# %%
# Gráfico da previsão x teste
from statsmodels.tsa.ar_model import AutoReg
result = workload[-test_len+29:-1].copy()
result['predict'] = predict[:]

plt.figure(figsize=(6,4))
#plt.plot(train_set, label = 'Treino')
plt.plot(result['cpu'], label = 'Teste')
plt.plot(result['predict'], label = 'Previsão')
plt.xlabel('tempo')
plt.ylabel('% cpu')
plt.legend()
plt.show()

# %% [markdown]
# ### Validação do modelo
# Na validação do modelo foi utilizada a técnica do erro quadrático médio, com o método 'mse' da biblioteca statsmodels.
# Este método recebe como parâmetro o conjunto de teste e a previsão gerada pelo modelo. O resultado apresentado significa a taxa de erro, quanto menor melhor.

# %%
mse(result['cpu'], result['predict'])
# Out:
# 4.819926207918737
